# %%
import cv2
from skimage import io, color
from IPython.display import Image

# %%
Image(url="img/grupo_pessoas.jpg")
# Out:
# <img src="img/grupo_pessoas.jpg"/>

# %%
img_grupo1 = io.imread("img/grupo_pessoas.jpg")
io.imshow(img_grupo1)
io.show()
# Out:
# C:\Users\fabio\AppData\Local\Temp\ipykernel_15508\1247543498.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(img_grupo1)
# C:\Users\fabio\AppData\Local\Temp\ipykernel_15508\1247543498.py:3: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
img_grupo1 = cv2.imread("img/grupo_pessoas.jpg")
img_grupo1.shape
# Out:
# (2600, 5252, 3)

# %%
img_grey = color.rgb2gray(img_grupo1)
io.imshow(img_grey)
io.show()
# Out:
# C:\Users\fabio\AppData\Local\Temp\ipykernel_15508\2784431617.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(img_grey)
# C:\Users\fabio\AppData\Local\Temp\ipykernel_15508\2784431617.py:3: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
grayImage1 = cv2.cvtColor(img_grupo1, cv2.COLOR_BGR2GRAY)
grayImage1.shape
# Out:
# (2600, 5252)

# %%
face_parametro = "cascade/frontalface_alt.xml"
classificador_cascade = cv2.CascadeClassifier(face_parametro)

# %%
classificador_cascade
# Out:
# < cv2.CascadeClassifier 000001EAF178BAB0>

# %%
faces = classificador_cascade.detectMultiScale(grayImage1, scaleFactor=1.1, minNeighbors=6, minSize=(20,20))

# %%
faces
# Out:
# array([[ 774, 1081,   84,   84],
#        [ 454,  861,  118,  118],
#        [1211, 1037,  115,  115],
#        [ 629,  960,  121,  121],
#        [2636, 1149,   92,   92],
#        [3255, 1153,   99,   99],
#        [2163, 1174,   89,   89],
#        [3523, 1171,  110,  110],
#        [2509, 1537,  101,  101],
#        [4234, 1551,  122,  122],
#        [1573, 1389,  116,  116],
#        [3377, 1214,   98,   98],
#        [1325, 1075,  115,  115],
#        [3364, 1454,  118,  118],
#        [2276, 1576,  102,  102],
#        [2952, 1575,  112,  112],
#        [4240, 1007,  116,  116],
#        [2441, 1084,  111,  111],
#        [3228, 1677,   61,   61],
#        [ 984, 1021,  123,  123],
#        [2026, 1460,  107,  107],
#        [1028, 1472,  122,  122],
#        [1355, 1576,  134,  134],
#        [3622, 1572,  136,  136],
#        [3863, 1026,   97,   97],
#        [2296, 1137,  105,  105],
#        [4002, 1104,  114,  114],
#        [1862, 1222,  110,  110],
# ...

# %%
for (x,y, width, height) in faces:
    cv2.rectangle(img_grupo1, (x,y), (x + width, y + height), (0, 255, 0), 6)

# %%
cv2.imwrite("img/resultado_grupo1.jpg", img_grupo1)
# Out:
# True
